# %%
# %load_ext autoreload
# %autoreload 2

# %%
# =============================================================================
#  Import Section: LOAD DATA
# =============================================================================

# Python lib/std-pkgs imports
import os
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load Data Imports
import load_data as ld
from rawDataHandler import RawDataHandler, NodeDfStore

# %%
# =============================================================================
#  Load dataframe with metrics
# =============================================================================

src_folder = "/home/daniel/Documents/00_DNA/DASH/dash-repo/code/rf_output/francis-2020-07-09-more/"
read_path_mode = src_folder + "log_mode.csv"
read_path_nseg = src_folder + "log_nseg.csv"
read_path_gnb = src_folder + "log_gnb.csv"

df_mode = pd.read_csv(read_path_mode)
df_nseg = pd.read_csv(read_path_nseg)
df_gnb = pd.read_csv(read_path_gnb)

# %%
df_mode
# Out:
#     Unnamed: 0  mode_n_trees  mode_tree_depth  mode_cv_mean_auc  train_acc  \
# 0            0             5                5          0.972144   0.822438
# 1            1             5               10          0.979205   0.915209
# 2            2             5               15          0.971761   0.962613
# 3            3             5               20          0.964365   0.971374
# 4            4             5               25          0.963126   0.971541
# ..         ...           ...              ...               ...        ...
# 94          94            45               35          0.984727   0.986719
# 95          95            45               40          0.984733   0.986719
# 96          96            45               45          0.984733   0.986719
# 97          97            45               50          0.984733   0.986719
# 98          98            45               55          0.984733   0.986719
#
#     mode_test_auc  test_acc                                    mode_image_path
# 0        0.973808  0.818950  ./rf_output/francis-2020-07-09-more/rf_mode_be...
# 1        0.980745  0.857789  ./rf_output/francis-2020-07-09-more/rf_mode_be...
# 2        0.973370  0.856700  ./rf_output/francis-2020-07-09-more/rf_mode_be...
# 3        0.964626  0.852599  ./rf_output/francis-2020-07-09-more/rf_mode_be...
# 4        0.963604  0.851092  ./rf_output/francis-2020-07-09-more/rf_mode_be...
# ..            ...       ...                                                ...
# 94       0.985644  0.875115  ./rf_output/francis-2020-07-09-more/rf_mode_be...
# 95       0.985646  0.875450  ./rf_output/francis-2020-07-09-more/rf_mode_be...
# 96       0.985646  0.875450  ./rf_output/francis-2020-07-09-more/rf_mode_be...
# 97       0.985646  0.875450  ./rf_output/francis-2020-07-09-more/rf_mode_be...
# 98       0.985646  0.875450  ./rf_output/francis-2020-07-09-more/rf_mode_be...
#
# [99 rows x 8 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
X,Y = np.meshgrid(df_mode['mode_n_trees'].values,df_mode['mode_tree_depth'].values)
print(X.shape)
print(Y.shape)
Z = df_mode['mode_test_auc'].values
print(Z.shape)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z)
# Out:
# (99, 99)
# (99, 99)
# (99,)
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# <ipython-input-21-7adadd0cc076> in <module>
#       6 fig = plt.figure()
#       7 ax = fig.add_subplot(111, projection='3d')
# ----> 8 ax.plot_surface(X, Y, Z)
#
# ~/miniconda3/envs/dashml/lib/python3.8/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1580
#    1581         if Z.ndim != 2:
# -> 1582             raise ValueError("Argument Z must be 2-dimensional.")
#    1583         if np.any(np.isnan(Z)):
#    1584             cbook._warn_external(
#
# ValueError: Argument Z must be 2-dimensional.

# %%
from matplotlib import cm
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_trisurf(df_mode['mode_n_trees'], df_mode['mode_tree_depth'], df_mode['mode_test_auc'], cmap=cm.coolwarm, linewidth=0.2)
plt.show()
